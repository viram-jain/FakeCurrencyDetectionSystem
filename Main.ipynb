# %%
#import all necessary modules
from keras.applications.resnet50 import ResNet50,preprocess_input
from keras.preprocessing.image import ImageDataGenerator,image 
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.models import Sequential,Model,load_model
from keras import optimizers
from keras.callbacks import ModelCheckpoint,EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
#define height and width of the image
height=300
width=300

#create a ResNet50 model instance without the top layer as we will add our own top layer
base_model=ResNet50(weights='imagenet',include_top=False,input_shape=(height,width,3))

# %%
#define directory containing training and validation data
train_dir="Dataset/Training"
validation_dir="Dataset/Validation"

#number of batches the data has to be divided into
batch_size=8

#create datagen and generator to load the data from training directory
train_datagen=ImageDataGenerator(preprocessing_function=preprocess_input,rotation_range=90,horizontal_flip=True,vertical_flip=True)
train_generator=train_datagen.flow_from_directory(train_dir,target_size=(height,width),batch_size=batch_size)

#create datagen and generator to load the data from validation directory
validation_datagen=ImageDataGenerator(preprocessing_function=preprocess_input,rotation_range=90,horizontal_flip=True,vertical_flip=True)
validation_generator=validation_datagen.flow_from_directory(validation_dir,target_size=(height,width),batch_size=batch_size)
# Out:
# Found 35 images belonging to 2 classes.
# Found 7 images belonging to 2 classes.

# %%
#our own model which will be added onto the ResNet50 model
def build_finetune_model(base_model,dropout,fc_layers,num_classes):
    for layer in base_model.layers:
        layer.trainable=False

    x=base_model.output
    x=Flatten()(x)
    for fc in fc_layers:
        x=Dense(fc,activation='relu')(x)
        x=Dropout(dropout)(x)
    
    predictions=Dense(num_classes,activation='softmax')(x)

    finetune_model=Model(inputs=base_model.input,outputs=predictions) 
    
    return finetune_model

class_list=['Real','Fake'] #the labels of our data
FC_Layers=[1024,1024]
dropout=0.5

finetune_model=build_finetune_model(base_model,dropout=dropout,fc_layers=FC_Layers,num_classes=len(class_list))

# %%
#define number of epochs(the number of times the model will be trained) and number of training images
num_epochs=100
num_train_images=35

# %%
#checkpoint in case anything goes wrong
checkpoint=ModelCheckpoint("Final_model.h5",monitor='val_acc',verbose=1,save_best_only=True,save_weights_only=False,mode='auto',period=1)
early=EarlyStopping(monitor='val_acc',min_delta=0,patience=40,verbose=1,mode="auto")

#compile the model before using
finetune_model.compile(loss="categorical_crossentropy",optimizer=optimizers.SGD(lr=0.000001,momentum=0.9),metrics=['accuracy'])

#train the model
finetune_model.fit_generator(generator=train_generator,steps_per_epoch=num_train_images//batch_size,epochs=num_epochs,validation_data=validation_generator,validation_steps=1,callbacks=[checkpoint,early])

#save the model
finetune_model.save_weights("Final_model.h5")
# Out:
# Epoch 1/100
# 4/4 [==============================] - 36s 9s/step - loss: 1.1971 - accuracy: 0.5556 - val_loss: 0.6288 - val_accuracy: 0.7143
# Epoch 2/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.1059 - accuracy: 0.5556 - val_loss: 1.1342 - val_accuracy: 0.4286
# Epoch 3/100
# 4/4 [==============================] - 36s 9s/step - loss: 1.1302 - accuracy: 0.5938 - val_loss: 0.4333 - val_accuracy: 0.8571
# Epoch 4/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.0328 - accuracy: 0.4815 - val_loss: 0.4078 - val_accuracy: 0.7143
# Epoch 5/100
# 4/4 [==============================] - 33s 8s/step - loss: 1.4231 - accuracy: 0.6667 - val_loss: 0.7536 - val_accuracy: 0.7143
# Epoch 6/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.0079 - accuracy: 0.5926 - val_loss: 0.4235 - val_accuracy: 0.8571
# Epoch 7/100
# 4/4 [==============================] - 36s 9s/step - loss: 1.4245 - accuracy: 0.5312 - val_loss: 0.6144 - val_accuracy: 0.8571
# Epoch 8/100
# 4/4 [==============================] - 29s 7s/step - loss: 0.8801 - accuracy: 0.6364 - val_loss: 0.7569 - val_accuracy: 0.7143
# Epoch 9/100
# 4/4 [==============================] - 36s 9s/step - loss: 1.2779 - accuracy: 0.6250 - val_loss: 0.7194 - val_accuracy: 0.7143
# Epoch 10/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.0856 - accuracy: 0.5926 - val_loss: 0.8168 - val_accuracy: 0.5714
# Epoch 11/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.3059 - accuracy: 0.5312 - val_loss: 0.3234 - val_accuracy: 0.8571
# Epoch 12/100
# 4/4 [==============================] - 28s 7s/step - loss: 1.6695 - accuracy: 0.5455 - val_loss: 0.6380 - val_accuracy: 0.7143
# Epoch 13/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.2366 - accuracy: 0.5625 - val_loss: 0.3756 - val_accuracy: 0.8571
# Epoch 14/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.1361 - accuracy: 0.6667 - val_loss: 0.5113 - val_accuracy: 0.8571
# Epoch 15/100
# 4/4 [==============================] - 32s 8s/step - loss: 2.1633 - accuracy: 0.5185 - val_loss: 0.5316 - val_accuracy: 0.7143
# Epoch 16/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.2916 - accuracy: 0.5556 - val_loss: 0.5313 - val_accuracy: 0.7143
# Epoch 17/100
# 4/4 [==============================] - 36s 9s/step - loss: 1.4416 - accuracy: 0.5938 - val_loss: 0.6995 - val_accuracy: 0.7143
# Epoch 18/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.6025 - accuracy: 0.4815 - val_loss: 1.3393 - val_accuracy: 0.5714
# Epoch 19/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.3166 - accuracy: 0.5556 - val_loss: 1.4632 - val_accuracy: 0.7143
# Epoch 20/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.1354 - accuracy: 0.5185 - val_loss: 0.6723 - val_accuracy: 0.5714
# Epoch 21/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.5763 - accuracy: 0.4815 - val_loss: 1.2861 - val_accuracy: 0.7143
# Epoch 22/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.4337 - accuracy: 0.5556 - val_loss: 0.9379 - val_accuracy: 0.7143
# Epoch 23/100
# 4/4 [==============================] - 36s 9s/step - loss: 1.5630 - accuracy: 0.4688 - val_loss: 1.0052 - val_accuracy: 0.5714
# Epoch 24/100
# 4/4 [==============================] - 34s 8s/step - loss: 1.2749 - accuracy: 0.5556 - val_loss: 0.7622 - val_accuracy: 0.8571
# Epoch 25/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.4433 - accuracy: 0.5556 - val_loss: 0.5856 - val_accuracy: 0.7143
# Epoch 26/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.2411 - accuracy: 0.6296 - val_loss: 0.4070 - val_accuracy: 0.7143
# Epoch 27/100
# 4/4 [==============================] - 36s 9s/step - loss: 1.4315 - accuracy: 0.5312 - val_loss: 0.6055 - val_accuracy: 0.5714
# Epoch 28/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.0062 - accuracy: 0.5185 - val_loss: 0.4909 - val_accuracy: 0.7143
# Epoch 29/100
# 4/4 [==============================] - 29s 7s/step - loss: 0.7322 - accuracy: 0.5909 - val_loss: 0.7500 - val_accuracy: 0.8571
# Epoch 30/100
# 4/4 [==============================] - 36s 9s/step - loss: 1.2603 - accuracy: 0.6250 - val_loss: 0.7511 - val_accuracy: 0.5714
# Epoch 31/100
# 4/4 [==============================] - 31s 8s/step - loss: 0.7408 - accuracy: 0.7037 - val_loss: 0.6468 - val_accuracy: 0.5714
# Epoch 32/100
# 4/4 [==============================] - 33s 8s/step - loss: 1.2612 - accuracy: 0.5556 - val_loss: 0.6236 - val_accuracy: 0.7143
# Epoch 33/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.6590 - accuracy: 0.4688 - val_loss: 0.9710 - val_accuracy: 0.7143
# Epoch 34/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.2740 - accuracy: 0.5185 - val_loss: 0.6556 - val_accuracy: 0.7143
# Epoch 35/100
# 4/4 [==============================] - 32s 8s/step - loss: 0.7177 - accuracy: 0.6667 - val_loss: 0.9838 - val_accuracy: 0.7143
# Epoch 36/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.3295 - accuracy: 0.5556 - val_loss: 0.5999 - val_accuracy: 0.7143
# Epoch 37/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.3051 - accuracy: 0.5926 - val_loss: 0.4711 - val_accuracy: 0.8571
# Epoch 38/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.1369 - accuracy: 0.6562 - val_loss: 0.8317 - val_accuracy: 0.5714
# Epoch 39/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.4126 - accuracy: 0.4815 - val_loss: 0.6394 - val_accuracy: 0.8571
# Epoch 40/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.5107 - accuracy: 0.6667 - val_loss: 0.6768 - val_accuracy: 0.7143
# Epoch 41/100
# 4/4 [==============================] - 31s 8s/step - loss: 0.8158 - accuracy: 0.7037 - val_loss: 0.8995 - val_accuracy: 0.4286
# Epoch 42/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.0552 - accuracy: 0.5000 - val_loss: 0.9869 - val_accuracy: 0.5714
# Epoch 43/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.0440 - accuracy: 0.6667 - val_loss: 1.2144 - val_accuracy: 0.5714
# Epoch 44/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.3851 - accuracy: 0.5185 - val_loss: 0.7091 - val_accuracy: 0.7143
# Epoch 45/100
# 4/4 [==============================] - 32s 8s/step - loss: 0.9653 - accuracy: 0.6296 - val_loss: 0.6245 - val_accuracy: 0.5714
# Epoch 46/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.0589 - accuracy: 0.6296 - val_loss: 0.7224 - val_accuracy: 0.7143
# Epoch 47/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.3624 - accuracy: 0.5625 - val_loss: 0.4039 - val_accuracy: 0.8571
# Epoch 48/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.0998 - accuracy: 0.7037 - val_loss: 0.7116 - val_accuracy: 0.5714
# Epoch 49/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.0473 - accuracy: 0.5926 - val_loss: 0.3639 - val_accuracy: 0.8571
# Epoch 50/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.5911 - accuracy: 0.4815 - val_loss: 1.0034 - val_accuracy: 0.7143
# Epoch 51/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.0187 - accuracy: 0.6296 - val_loss: 0.5999 - val_accuracy: 0.7143
# Epoch 52/100
# 4/4 [==============================] - 31s 8s/step - loss: 0.6839 - accuracy: 0.7407 - val_loss: 0.5804 - val_accuracy: 0.5714
# Epoch 53/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.4787 - accuracy: 0.4815 - val_loss: 0.6707 - val_accuracy: 0.7143
# Epoch 54/100
# 4/4 [==============================] - 38s 9s/step - loss: 1.2071 - accuracy: 0.5312 - val_loss: 0.3357 - val_accuracy: 0.8571
# Epoch 55/100
# 4/4 [==============================] - 31s 8s/step - loss: 0.3426 - accuracy: 0.8519 - val_loss: 0.5470 - val_accuracy: 0.5714
# Epoch 56/100
# 4/4 [==============================] - 34s 9s/step - loss: 1.3350 - accuracy: 0.5625 - val_loss: 0.7898 - val_accuracy: 0.7143
# Epoch 57/100
# 4/4 [==============================] - 28s 7s/step - loss: 1.0117 - accuracy: 0.6818 - val_loss: 0.3908 - val_accuracy: 0.7143
# Epoch 58/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.0575 - accuracy: 0.5556 - val_loss: 0.5673 - val_accuracy: 0.8571
# Epoch 59/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.3673 - accuracy: 0.6250 - val_loss: 0.2450 - val_accuracy: 1.0000
# Epoch 60/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.4792 - accuracy: 0.5556 - val_loss: 0.5108 - val_accuracy: 0.7143
# Epoch 61/100
# 4/4 [==============================] - 31s 8s/step - loss: 0.7752 - accuracy: 0.6296 - val_loss: 0.6486 - val_accuracy: 0.7143
# Epoch 62/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.1729 - accuracy: 0.5938 - val_loss: 0.4556 - val_accuracy: 0.8571
# Epoch 63/100
# 4/4 [==============================] - 29s 7s/step - loss: 1.1290 - accuracy: 0.6364 - val_loss: 1.0077 - val_accuracy: 0.5714
# Epoch 64/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.0819 - accuracy: 0.6667 - val_loss: 0.7629 - val_accuracy: 0.4286
# Epoch 65/100
# 4/4 [==============================] - 35s 9s/step - loss: 0.7278 - accuracy: 0.7188 - val_loss: 0.6945 - val_accuracy: 0.7143
# Epoch 66/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.0689 - accuracy: 0.5556 - val_loss: 0.5937 - val_accuracy: 0.7143
# Epoch 67/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.5160 - accuracy: 0.5625 - val_loss: 0.5522 - val_accuracy: 0.7143
# Epoch 68/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.6336 - accuracy: 0.5556 - val_loss: 0.2256 - val_accuracy: 1.0000
# Epoch 69/100
# 4/4 [==============================] - 28s 7s/step - loss: 1.4843 - accuracy: 0.5000 - val_loss: 0.3273 - val_accuracy: 1.0000
# Epoch 70/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.1972 - accuracy: 0.5625 - val_loss: 0.4625 - val_accuracy: 0.7143
# Epoch 71/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.2426 - accuracy: 0.5926 - val_loss: 0.7953 - val_accuracy: 0.7143
# Epoch 72/100
# 4/4 [==============================] - 35s 9s/step - loss: 0.7337 - accuracy: 0.6875 - val_loss: 0.8581 - val_accuracy: 0.7143
# Epoch 73/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.2991 - accuracy: 0.5926 - val_loss: 0.5633 - val_accuracy: 0.8571
# Epoch 74/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.0817 - accuracy: 0.6296 - val_loss: 0.3970 - val_accuracy: 0.8571
# Epoch 75/100
# 4/4 [==============================] - 31s 8s/step - loss: 0.9851 - accuracy: 0.6296 - val_loss: 0.5166 - val_accuracy: 0.7143
# Epoch 76/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.1403 - accuracy: 0.5926 - val_loss: 0.9250 - val_accuracy: 0.7143
# Epoch 77/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.1645 - accuracy: 0.6296 - val_loss: 0.4066 - val_accuracy: 0.8571
# Epoch 78/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.2327 - accuracy: 0.6250 - val_loss: 0.5545 - val_accuracy: 0.5714
# Epoch 79/100
# 4/4 [==============================] - 31s 8s/step - loss: 0.7874 - accuracy: 0.7407 - val_loss: 0.6349 - val_accuracy: 0.8571
# Epoch 80/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.0196 - accuracy: 0.5556 - val_loss: 0.8579 - val_accuracy: 0.8571
# Epoch 81/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.1532 - accuracy: 0.7037 - val_loss: 0.7564 - val_accuracy: 0.7143
# Epoch 82/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.4082 - accuracy: 0.4815 - val_loss: 0.3262 - val_accuracy: 0.8571
# Epoch 83/100
# 4/4 [==============================] - 35s 9s/step - loss: 0.9873 - accuracy: 0.6250 - val_loss: 0.4506 - val_accuracy: 0.7143
# Epoch 84/100
# 4/4 [==============================] - 28s 7s/step - loss: 0.4198 - accuracy: 0.8636 - val_loss: 0.4352 - val_accuracy: 0.7143
# Epoch 85/100
# 4/4 [==============================] - 35s 9s/step - loss: 0.6027 - accuracy: 0.7188 - val_loss: 0.8535 - val_accuracy: 0.7143
# Epoch 86/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.0214 - accuracy: 0.6296 - val_loss: 0.2695 - val_accuracy: 1.0000
# Epoch 87/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.3473 - accuracy: 0.4074 - val_loss: 0.6347 - val_accuracy: 0.8571
# Epoch 88/100
# 4/4 [==============================] - 31s 8s/step - loss: 0.4121 - accuracy: 0.8148 - val_loss: 0.3993 - val_accuracy: 0.7143
# Epoch 89/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.2628 - accuracy: 0.6562 - val_loss: 0.2727 - val_accuracy: 0.8571
# Epoch 90/100
# 4/4 [==============================] - 31s 8s/step - loss: 0.8985 - accuracy: 0.6667 - val_loss: 0.7840 - val_accuracy: 0.7143
# Epoch 91/100
# 4/4 [==============================] - 34s 9s/step - loss: 1.1107 - accuracy: 0.5938 - val_loss: 0.9445 - val_accuracy: 0.7143
# Epoch 92/100
# 4/4 [==============================] - 32s 8s/step - loss: 1.2706 - accuracy: 0.5556 - val_loss: 0.1510 - val_accuracy: 1.0000
# Epoch 93/100
# 4/4 [==============================] - 28s 7s/step - loss: 1.1423 - accuracy: 0.6364 - val_loss: 0.6534 - val_accuracy: 0.8571
# Epoch 94/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.2633 - accuracy: 0.7037 - val_loss: 1.0050 - val_accuracy: 0.7143
# Epoch 95/100
# 4/4 [==============================] - 35s 9s/step - loss: 1.0720 - accuracy: 0.5625 - val_loss: 0.7784 - val_accuracy: 0.8571
# Epoch 96/100
# 4/4 [==============================] - 34s 9s/step - loss: 0.9605 - accuracy: 0.5625 - val_loss: 0.4642 - val_accuracy: 0.8571
# Epoch 97/100
# 4/4 [==============================] - 31s 8s/step - loss: 0.8145 - accuracy: 0.5926 - val_loss: 0.5556 - val_accuracy: 0.5714
# Epoch 98/100
# 4/4 [==============================] - 31s 8s/step - loss: 1.1725 - accuracy: 0.5926 - val_loss: 0.6265 - val_accuracy: 0.8571
# Epoch 99/100
# 4/4 [==============================] - 28s 7s/step - loss: 1.2373 - accuracy: 0.4545 - val_loss: 0.8915 - val_accuracy: 0.5714
# Epoch 100/100
# 4/4 [==============================] - 35s 9s/step - loss: 0.6745 - accuracy: 0.8125 - val_loss: 1.0077 - val_accuracy: 0.7143

# %%
#testing the model
img=image.load_img("Dataset/Testing/Real.jpg",target_size=(300,300)) #The path of the testing image,the pic taken from the phone should come here
img=np.asarray(img)
plt.imshow(img)
img=np.expand_dims(img,axis=0)
finetune_model.load_weights("Final_model.h5")

output=finetune_model.predict(img) #predicting the image using model created
if(output[0][0]>output[0][1]): #comparison
    print("Fake")
else:
    print("Real")
# Out:
# Real

# %%
#testing the model
img=image.load_img("Dataset/Testing/Fake.jpeg",target_size=(300,300)) #The path of the testing image,the pic taken from the phone should come here
img=np.asarray(img)
plt.imshow(img)
img=np.expand_dims(img,axis=0)
finetune_model.load_weights("Final_model.h5")

output=finetune_model.predict(img) #predicting the image using model created
if(output[0][0]>output[0][1]): #comparison
    print("Fake")
else:
    print("Real")
# Out:
# Fake
